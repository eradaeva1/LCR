# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as pltv

# %%
#H0: no sagnificant relationship between house size and house price (B1 = 0)
#H1L: there is a sagnificant linear relationship between house size and house price (B1 )

# %%
# Plot the relationship between x and y
plt.scatter(sacramento["sq__ft"], sacramento["price"], label='House size vs House price')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Plot the relationship between x and y
# ----> 2 plt.scatter(sacramento["sq__ft"], sacramento["price"], label='House size vs House price')
#
# NameError: name 'plt' is not defined
